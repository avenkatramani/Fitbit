# %%
import fitbit
import gather_keys_oauth2 as Oauth2
import pandas as pd 
import datetime

# %%
CLIENT_ID = '22D97S'
CLIENT_SECRET = '6046f7928eefdce230907a4e13f2776b'
server = Oauth2.OAuth2Server(CLIENT_ID, CLIENT_SECRET)
server.browser_authorize()
ACCESS_TOKEN = str(server.fitbit.client.session.token['access_token'])
REFRESH_TOKEN = str(server.fitbit.client.session.token['refresh_token'])
auth2_client = fitbit.Fitbit(CLIENT_ID, CLIENT_SECRET, oauth2=True, access_token=ACCESS_TOKEN, refresh_token=REFRESH_TOKEN)
# Out:
# [10/Jan/2019:16:36:44] ENGINE Listening for SIGHUP.
# [10/Jan/2019:16:36:44] ENGINE Listening for SIGTERM.
# [10/Jan/2019:16:36:44] ENGINE Listening for SIGUSR1.
# [10/Jan/2019:16:36:44] ENGINE Bus STARTING
# [10/Jan/2019:16:36:44] ENGINE Started monitor thread 'Autoreloader'.
# [10/Jan/2019:16:36:44] ENGINE Serving on http://127.0.0.1:8080
# [10/Jan/2019:16:36:44] ENGINE Bus STARTED
# 127.0.0.1 - - [10/Jan/2019:16:36:45] "GET /?code=14f859bfd594e392d95391a17111fcede77769ff&state=EWnYzBDujt5deUd9GnYExsKG6E86AI HTTP/1.1" 200 122 "" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36"
# [10/Jan/2019:16:36:46] ENGINE Bus STOPPING
# [10/Jan/2019:16:36:51] ENGINE HTTP Server cherrypy._cpwsgi_server.CPWSGIServer(('127.0.0.1', 8080)) shut down
# [10/Jan/2019:16:36:51] ENGINE Stopped thread 'Autoreloader'.
# [10/Jan/2019:16:36:51] ENGINE Bus STOPPED
# [10/Jan/2019:16:36:51] ENGINE Bus EXITING
# [10/Jan/2019:16:36:51] ENGINE Bus EXITED
# [10/Jan/2019:16:36:51] ENGINE Waiting for child threads to terminate...

# %%
yesterday = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y%m%d"))
yesterday2 = str((datetime.datetime.now() - datetime.timedelta(days=1)).strftime("%Y-%m-%d"))
today = str(datetime.datetime.now().strftime("%Y%m%d"))

# %%
auth2_client.activities()
# Out:
# {u'activities': [],
#  u'goals': {u'activeMinutes': 30,
#   u'caloriesOut': 2752,
#   u'distance': 5,
#   u'floors': 10,
#   u'steps': 8000},
#  u'summary': {u'activeScore': -1,
#   u'activityCalories': 519,
#   u'caloriesBMR': 1141,
#   u'caloriesOut': 1591,
#   u'distances': [{u'activity': u'total', u'distance': 2.17},
#    {u'activity': u'tracker', u'distance': 2.17},
#    {u'activity': u'loggedActivities', u'distance': 0},
#    {u'activity': u'veryActive', u'distance': 1.02},
#    {u'activity': u'moderatelyActive', u'distance': 0.17},
#    {u'activity': u'lightlyActive', u'distance': 0.98},
#    {u'activity': u'sedentaryActive', u'distance': 0}],
#   u'elevation': 170,
#   u'fairlyActiveMinutes': 9,
#   u'floors': 17,
#   u'heartRateZones': [{u'caloriesOut': 1226.8712,
#     u'max': 98,
#     u'min': 30,
#     u'minutes': 934,
#     u'name': u'Out of Range'},
#    {u'caloriesOut': 331.84376,
#     u'max': 137,
#     u'min': 98,
#     u'minutes': 46,
#     u'name': u'Fat Burn'},
#    {u'caloriesOut': 0,
#     u'max': 166,
#     u'min': 137,
#     u'minutes': 0,
#     u'name': u'Cardio'},
#    {u'caloriesOut': 0,
#     u'max': 220,
#     u'min': 166,
#     u'minutes': 0,
#     u'name': u'Peak'}],
#   u'lightlyActiveMinutes': 63,
#   u'marginalCalories': 330,
#   u'restingHeartRate': 62,
#   u'sedentaryMinutes': 300,
#   u'steps': 4949,
#   u'veryActiveMinutes': 26}}

# %%
fit_statsHR = auth2_client.intraday_time_series('activities/heart', base_date=yesterday2, detail_level='1sec')

# %%
time_list = []
val_list = []
for i in fit_statsHR['activities-heart-intraday']['dataset']:
    val_list.append(i['value'])
    time_list.append(i['time'])
heartdf = pd.DataFrame({'Heart Rate':val_list,'Time':time_list})

# %%
heartdf
# Out:
#        Heart Rate      Time
# 0              79  00:10:16
# 1              70  00:10:21
# 2              70  00:10:26
# 3              87  00:10:36
# 4             106  00:10:41
# 5              98  00:10:46
# 6              97  00:10:51
# 7              95  00:10:56
# 8              91  00:11:01
# 9              94  00:11:06
# 10            109  00:11:11
# 11            110  00:11:26
# 12            111  00:11:31
# 13            100  00:11:36
# 14             98  00:11:41
# 15            100  00:11:46
# 16             96  00:11:56
# 17             97  00:12:01
# 18             99  00:12:06
# 19             98  00:12:11
# 20             96  00:12:16
# 21             94  00:12:21
# 22             93  00:12:26
# 23             94  00:12:41
# 24             93  00:12:51
# 25             94  00:12:56
# 26             93  00:13:01
# 27             97  00:13:06
# 28             98  00:13:11
# 29             96  00:13:21
# ...           ...       ...
# 10348          78  23:54:29
# 10349          80  23:54:34
# 10350          79  23:54:39
# 10351          77  23:54:44
# 10352          74  23:54:49
# 10353          61  23:54:54
# 10354          56  23:54:59
# 10355          56  23:55:14
# 10356          56  23:55:29
# 10357          57  23:55:34
# 10358          58  23:55:44
# 10359          57  23:55:59
# 10360          57  23:56:14
# 10361          55  23:56:24
# 10362          56  23:56:34
# 10363          56  23:56:39
# 10364          57  23:56:44
# 10365          58  23:56:49
# 10366          57  23:56:59
# 10367          56  23:57:09
# 10368          57  23:57:24
# 10369          58  23:57:34
# 10370          57  23:57:44
# 10371          58  23:57:54
# 10372          57  23:57:59
# 10373          58  23:58:04
# 10374          57  23:58:09
# 10375          58  23:58:24
# 10376          58  23:58:39
# 10377          57  23:58:54
#
# [10378 rows x 2 columns]
